# %% [markdown]
# # Performance Profiling of Contextual Detector

# %%
from __future__ import division
from __future__ import print_function

import os
import sys
from time import time

# temporary solution for relative imports in case pyod is not installed
# if pyod is installed, no need to use the following line
sys.path.append(
    os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

import numpy as np
from numpy import percentile
import matplotlib.pyplot as plt
import matplotlib.font_manager

# Import all models
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.feature_bagging import FeatureBagging
from pyod.models.hbos import HBOS
from pyod.models.iforest import IForest
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.pca import PCA
from pyod.models.lscp import LSCP
from pyod.models.contextual import ContextualDetector
from pyod.utils import generate_contextual_data

# %%
outliers_fraction = 0.1

# initialize a set of detectors for LSCP
detector_list = [LOF(n_neighbors=5), LOF(n_neighbors=10), LOF(n_neighbors=15),
                 LOF(n_neighbors=20), LOF(n_neighbors=25), LOF(n_neighbors=30),
                 LOF(n_neighbors=35), LOF(n_neighbors=40), LOF(n_neighbors=45),
                 LOF(n_neighbors=50)]

# %%
random_state = np.random.RandomState(42)
# Define nine outlier detection tools to be compared
classifiers = {
    'ABOD':
        ABOD(contamination=outliers_fraction),
    'CBLOF':
        CBLOF(contamination=outliers_fraction,
              check_estimator=False, random_state=random_state),
    'Feature Bagging':
        FeatureBagging(LOF(n_neighbors=35),
                       contamination=outliers_fraction,
                       random_state=random_state),
    'HBOS': HBOS(
        contamination=outliers_fraction),
    'Isolation Forest': IForest(contamination=outliers_fraction,
                                behaviour="new",
                                random_state=random_state),
    'KNN': KNN(
        contamination=outliers_fraction),
    'Average KNN': KNN(method='mean',
                       contamination=outliers_fraction),
    'LOF':
        LOF(n_neighbors=35, contamination=outliers_fraction),
    'MCD': MCD(
        contamination=outliers_fraction, random_state=random_state),
    'OCSVM': OCSVM(contamination=outliers_fraction),
    'PCA': PCA(
        contamination=outliers_fraction, random_state=random_state),
    'LSCP': LSCP(
        detector_list, contamination=outliers_fraction,
        random_state=random_state)
}

contextual_classifiers = {"Contextual " + k: ContextualDetector(base_detector=v) for k, v in classifiers.items()}
classifiers = {**classifiers, **contextual_classifiers}

# %%
X_train, X_test, y_train, y_test = generate_contextual_data(n_train=10000, n_test=10000)

# %%
def profile(classifier):
    # profile fit
    classifier.fit(X_train)

    # profile predict
    classifier.predict(X_test)

# %%
import cProfile
cProfile.run('profile(classifiers["Contextual LOF"])', sort="tottime")
# Out:
#          4292946 function calls (4282733 primitive calls) in 4.865 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     10002    0.580    0.000    1.052    0.000 {method 'query' of 'sklearn.neighbors.kd_tree.BinaryTree' objects}
#     30006    0.270    0.000    1.286    0.000 validation.py:362(check_array)
#     50025    0.206    0.000    0.206    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     20007    0.148    0.000    0.257    0.000 _methods.py:58(_mean)
#     10002    0.145    0.000    3.313    0.000 base.py:333(kneighbors)
#     10002    0.135    0.000    2.040    0.000 parallel.py:866(__call__)
#     10002    0.134    0.000    0.310    0.000 lof.py:478(_local_reachability_density)
#     30006    0.119    0.000    0.333    0.000 validation.py:40(_assert_all_finite)
#    420078    0.112    0.000    0.112    0.000 {built-in method builtins.hasattr}
#     10000    0.110    0.000    4.254    0.000 lof.py:437(_score_samples)
#    260112    0.101    0.000    0.101    0.000 {built-in method builtins.getattr}
#    130056    0.094    0.000    0.094    0.000 {built-in method numpy.array}
#     40008    0.084    0.000    0.175    0.000 parallel.py:78(get_active_backend)
#     20004    0.070    0.000    1.642    0.000 parallel.py:735(dispatch_one_batch)
#    310097    0.069    0.000    0.118    0.000 {built-in method builtins.isinstance}
# 20004/10002    0.068    0.000    0.105    0.000 parallel.py:669(_initialize_backend)
#     10002    0.066    0.000    0.192    0.000 parallel.py:584(__init__)
#     20004    0.064    0.000    0.192    0.000 _parallel_backends.py:187(get_nested_backend)
#     40002    0.053    0.000    0.113    0.000 validation.py:903(check_is_fitted)
#     30006    0.051    0.000    0.120    0.000 validation.py:153(_shape_repr)
#     20004    0.050    0.000    0.112    0.000 version.py:307(parse)
#     10000    0.049    0.000    4.651    0.000 contextual.py:64(row_wise)
#     10000    0.048    0.000    4.535    0.000 base.py:144(predict)
#     30006    0.047    0.000    0.151    0.000 validation.py:127(_num_samples)
#     20004    0.046    0.000    0.046    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#     30006    0.046    0.000    0.049    0.000 warnings.py:449(__enter__)
#     30006    0.046    0.000    0.090    0.000 warnings.py:159(_add_filter)
#     20004    0.045    0.000    0.099    0.000 parallel.py:209(__init__)
#     20013    0.045    0.000    0.045    0.000 {built-in method numpy.concatenate}
#         1    0.040    0.040    4.738    4.738 shape_base.py:270(apply_along_axis)
#     20007    0.038    0.000    0.295    0.000 fromnumeric.py:3014(mean)
#     10002    0.037    0.000    0.037    0.000 disk.py:41(memstr_to_bytes)
#     30016    0.036    0.000    0.086    0.000 numerictypes.py:365(issubdtype)
#    240175    0.036    0.000    0.041    0.000 {built-in method builtins.len}
#     10002    0.035    0.000    1.266    0.000 parallel.py:698(_dispatch)
#     10002    0.034    0.000    0.086    0.000 utility.py:327(invert_order)
#     10002    0.033    0.000    0.040    0.000 parallel.py:300(__call__)
#    130110    0.032    0.000    0.032    0.000 {built-in method builtins.issubclass}
#     90018    0.032    0.000    0.032    0.000 validation.py:180(<genexpr>)
#     10002    0.032    0.000    0.044    0.000 parallel.py:818(retrieve)
#     10002    0.032    0.000    1.149    0.000 parallel.py:220(__call__)
#     10006    0.032    0.000    0.032    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     10002    0.031    0.000    0.058    0.000 functools.py:44(update_wrapper)
#     30006    0.030    0.000    0.123    0.000 warnings.py:143(simplefilter)
#     30006    0.030    0.000    0.062    0.000 {method 'join' of 'str' objects}
#     30006    0.029    0.000    0.029    0.000 {method 'remove' of 'list' objects}
#     20004    0.029    0.000    0.047    0.000 shape_base.py:83(atleast_2d)
#     10000    0.029    0.000    0.029    0.000 contextual.py:66(<listcomp>)
#     10000    0.028    0.000    4.415    0.000 lof.py:176(decision_function)
#     10002    0.028    0.000    0.028    0.000 threading.py:74(RLock)
#     90032    0.027    0.000    0.069    0.000 numeric.py:541(asanyarray)
#     30006    0.026    0.000    0.029    0.000 warnings.py:468(__exit__)
#     30008    0.026    0.000    0.048    0.000 abc.py:180(__instancecheck__)
#     10003    0.025    0.000    0.025    0.000 {built-in method numpy.copyto}
#     60032    0.025    0.000    0.046    0.000 numerictypes.py:293(issubclass_)
#     20004    0.024    0.000    0.048    0.000 base.py:453(<genexpr>)
#     20004    0.024    0.000    0.152    0.000 shape_base.py:229(vstack)
#     40008    0.024    0.000    0.024    0.000 _parallel_backends.py:254(__init__)
#     30006    0.024    0.000    0.024    0.000 warnings.py:428(__init__)
#     40002    0.023    0.000    0.038    0.000 validation.py:950(<listcomp>)
#     10002    0.023    0.000    0.041    0.000 _parallel_backends.py:480(effective_n_jobs)
#     30010    0.023    0.000    0.023    0.000 _weakrefset.py:70(__contains__)
#     30006    0.022    0.000    0.032    0.000 validation.py:355(_ensure_no_complex_data)
#     20004    0.022    0.000    0.022    0.000 __init__.py:477(gen_even_slices)
#     10002    0.022    0.000    0.030    0.000 _parallel_backends.py:349(configure)
#     30006    0.021    0.000    0.175    0.000 {method 'sum' of 'numpy.ndarray' objects}
#     10002    0.021    0.000    0.086    0.000 parallel.py:264(delayed)
#     20010    0.019    0.000    0.024    0.000 _methods.py:48(_count_reduce_items)
#     10002    0.019    0.000    0.040    0.000 logger.py:39(short_format_time)
#     10002    0.019    0.000    0.019    0.000 {built-in method numpy.arange}
#     10000    0.019    0.000    0.024    0.000 utility.py:366(_sklearn_version_20)
#     40028    0.018    0.000    0.018    0.000 {method 'insert' of 'list' objects}
#     20004    0.016    0.000    0.023    0.000 <frozen importlib._bootstrap>:416(parent)
#     20004    0.016    0.000    0.016    0.000 version.py:312(<listcomp>)
#     40010    0.015    0.000    0.021    0.000 base.py:1190(isspmatrix)
#     30006    0.015    0.000    0.015    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     10002    0.014    0.000    0.049    0.000 validation.py:771(column_or_1d)
#     10002    0.014    0.000    1.211    0.000 _parallel_backends.py:180(apply_async)
#     10001    0.013    0.000    0.028    0.000 shape_base.py:373(<genexpr>)
#     10002    0.013    0.000    0.022    0.000 parallel.py:167(__init__)
#     20005    0.013    0.000    0.024    0.000 shape_base.py:220(_warn_for_nonsequence)
#     30006    0.013    0.000    0.021    0.000 _config.py:12(get_config)
# 30006/30005    0.013    0.000    0.016    0.000 {built-in method builtins.next}
#     20004    0.012    0.000    0.060    0.000 shape_base.py:283(<listcomp>)
#     10002    0.012    0.000    0.029    0.000 fromnumeric.py:1583(ravel)
#     10002    0.012    0.000    0.014    0.000 contextlib.py:59(__init__)
#     20009    0.011    0.000    0.011    0.000 {built-in method builtins.max}
#     30006    0.011    0.000    0.154    0.000 _methods.py:34(_sum)
#     10002    0.011    0.000    0.016    0.000 contextlib.py:85(__exit__)
#     30015    0.011    0.000    0.036    0.000 numeric.py:469(asarray)
#     10002    0.011    0.000    0.102    0.000 parallel.py:335(effective_n_jobs)
#     10002    0.011    0.000    1.071    0.000 parallel.py:224(<listcomp>)
#     10002    0.010    0.000    0.016    0.000 parallel.py:186(unregister)
#     20004    0.010    0.000    0.122    0.000 version.py:302(__init__)
#     10002    0.010    0.000    0.045    0.000 numeric.py:293(full)
#     40008    0.010    0.000    0.010    0.000 {built-in method time.time}
#     10003    0.010    0.000    0.010    0.000 {built-in method numpy.empty}
#     10002    0.010    0.000    0.012    0.000 version.py:331(_cmp)
#     50010    0.009    0.000    0.009    0.000 {built-in method builtins.setattr}
#     10002    0.009    0.000    0.021    0.000 logger.py:23(_squeeze_time)
#     10001    0.009    0.000    0.014    0.000 index_tricks.py:653(__next__)
#     10002    0.009    0.000    1.157    0.000 _parallel_backends.py:546(__init__)
#         1    0.009    0.009    0.126    0.126 contextual.py:23(fit)
#     90018    0.009    0.000    0.009    0.000 {built-in method _warnings._filters_mutated}
#     30008    0.008    0.000    0.008    0.000 {method 'copy' of 'dict' objects}
#     10004    0.008    0.000    0.008    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     10002    0.008    0.000    1.060    0.000 base.py:286(_tree_query_parallel_helper)
#     10000    0.008    0.000    4.542    0.000 contextual.py:56(<lambda>)
#     10002    0.007    0.000    0.007    0.000 functools.py:74(wraps)
#     20004    0.007    0.000    0.027    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#     40002    0.007    0.000    0.007    0.000 {built-in method builtins.all}
#     20004    0.007    0.000    0.007    0.000 {method 'rpartition' of 'str' objects}
#     10002    0.007    0.000    0.021    0.000 contextlib.py:157(helper)
#     20005    0.007    0.000    0.011    0.000 shape_base.py:209(_arrays_for_stack_dispatcher)
#     10002    0.007    0.000    0.022    0.000 parallel.py:183(__exit__)
#     10002    0.007    0.000    0.018    0.000 version.py:51(__lt__)
#     10002    0.006    0.000    0.008    0.000 threading.py:1230(current_thread)
#     40008    0.006    0.000    0.006    0.000 parallel.py:227(__len__)
#     10002    0.005    0.000    0.006    0.000 parallel.py:694(_terminate_backend)
#     10002    0.005    0.000    0.007    0.000 process.py:155(daemon)
#     20004    0.005    0.000    0.005    0.000 _parallel_backends.py:36(__init__)
#     10000    0.005    0.000    0.005    0.000 {method 'split' of 'str' objects}
#     10002    0.005    0.000    0.007    0.000 _parallel_backends.py:66(configure)
#     10002    0.005    0.000    0.005    0.000 parallel.py:295(__init__)
#     10006    0.005    0.000    0.005    0.000 {method 'startswith' of 'str' objects}
#     10002    0.005    0.000    0.005    0.000 {method 'pop' of 'list' objects}
#         2    0.005    0.002    0.107    0.053 lof.py:216(fit)
#     20004    0.004    0.000    0.004    0.000 parallel.py:762(_print)
#     10002    0.004    0.000    0.009    0.000 contextlib.py:79(__enter__)
#     10002    0.004    0.000    0.004    0.000 context.py:232(get_context)
#     40052    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#     10002    0.003    0.000    0.003    0.000 fromnumeric.py:1785(shape)
#     10002    0.003    0.000    0.003    0.000 _parallel_backends.py:201(effective_n_jobs)
#         2    0.003    0.002    0.003    0.002 base.py:164(_fit)
#     20004    0.003    0.000    0.003    0.000 _parallel_backends.py:133(retrieval_context)
#     10006    0.003    0.000    0.003    0.000 {method 'update' of 'dict' objects}
#     10002    0.003    0.000    0.003    0.000 _parallel_backends.py:589(__init__)
#     10002    0.003    0.000    0.003    0.000 parallel.py:775(print_progress)
#     20004    0.002    0.000    0.002    0.000 _parallel_backends.py:85(compute_batch_size)
#     10002    0.002    0.000    0.002    0.000 parallel.py:274(delayed_function)
#     10002    0.002    0.000    0.002    0.000 {built-in method _thread.get_ident}
#     10002    0.002    0.000    0.002    0.000 parallel.py:180(__enter__)
#     10410    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#     10002    0.002    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#     10002    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#     10002    0.002    0.000    0.002    0.000 _parallel_backends.py:174(effective_n_jobs)
#     10002    0.002    0.000    0.002    0.000 _parallel_backends.py:551(get)
#     10002    0.002    0.000    0.002    0.000 process.py:35(current_process)
#         2    0.001    0.001    0.109    0.055 lof.py:145(fit)
#        22    0.001    0.000    0.001    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#     10002    0.001    0.000    0.001    0.000 _parallel_backends.py:89(batch_completed)
#     10002    0.001    0.000    0.001    0.000 _parallel_backends.py:79(stop_call)
#     10002    0.001    0.000    0.001    0.000 _parallel_backends.py:76(start_call)
#     10002    0.001    0.000    0.001    0.000 _parallel_backends.py:82(terminate)
#         1    0.001    0.001    4.865    4.865 <ipython-input-25-42f7422cd651>:1(profile)
#     198/2    0.000    0.000    0.002    0.001 copy.py:132(deepcopy)
#         4    0.000    0.000    0.001    0.000 function_base.py:3846(_quantile_ureduce_func)
#         1    0.000    0.000    0.000    0.000 function_base.py:4220(delete)
#         4    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#        40    0.000    0.000    0.000    0.000 numeric.py:1557(normalize_axis_tuple)
#         2    0.000    0.000    0.000    0.000 {sklearn.neighbors.kd_tree.newObj}
#        20    0.000    0.000    0.000    0.000 numeric.py:1620(moveaxis)
#         3    0.000    0.000    0.000    0.000 _methods.py:91(_var)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method '__setstate__' of 'sklearn.neighbors.kd_tree.BinaryTree' objects}
#       6/2    0.000    0.000    0.002    0.001 copy.py:236(_deepcopy_dict)
#       8/2    0.000    0.000    0.002    0.001 copy.py:268(_reconstruct)
#         2    0.000    0.000    0.001    0.000 base.py:347(_process_decision_scores)
#         4    0.000    0.000    0.001    0.000 function_base.py:3354(_ureduce)
#         8    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        48    0.000    0.000    0.000    0.000 copy.py:252(_keep_alive)
#         4    0.000    0.000    0.001    0.000 function_base.py:3564(percentile)
#         2    0.000    0.000    0.000    0.000 base.py:233(__getstate__)
#       266    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         4    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 base.py:244(__setstate__)
#         3    0.000    0.000    0.000    0.000 _methods.py:138(_std)
#         1    0.000    0.000    0.112    0.112 contextual.py:34(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 function_base.py:3833(_quantile_is_valid)
#         2    0.000    0.000    0.000    0.000 {sklearn.neighbors.dist_metrics.newObj}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:54(_wrapfunc)
#        40    0.000    0.000    0.000    0.000 numeric.py:1607(<listcomp>)
#         8    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#         4    0.000    0.000    0.000    0.000 base.py:124(_check_algorithm_metric)
#         8    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:39(as_strided)
#         1    0.000    0.000    4.865    4.865 {built-in method builtins.exec}
#       4/2    0.000    0.000    0.000    0.000 copy.py:219(_deepcopy_tuple)
#        23    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 numeric.py:406(count_nonzero)
#         4    0.000    0.000    0.001    0.000 function_base.py:3821(_quantile_unchecked)
#        42    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.count_nonzero}
#       4/2    0.000    0.000    0.000    0.000 copy.py:220(<listcomp>)
#       148    0.000    0.000    0.000    0.000 copy.py:190(_deepcopy_atomic)
#         1    0.000    0.000    0.000    0.000 index_tricks.py:634(__init__)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:93(take)
#        16    0.000    0.000    0.000    0.000 copy.py:273(<genexpr>)
#         4    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:2083(any)
#         2    0.000    0.000    0.000    0.000 {method '__setstate__' of 'sklearn.neighbors.dist_metrics.DistanceMetric' objects}
#         1    0.000    0.000    0.003    0.003 contextual.py:33(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 lof.py:150(__init__)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3126(std)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2171(all)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:197(reshape)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:109(__init__)
#        40    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        20    0.000    0.000    0.000    0.000 numeric.py:1683(<listcomp>)
#        17    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    4.738    4.738 contextual.py:70(f)
#         8    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty_like}
#         2    0.000    0.000    0.003    0.002 base.py:920(fit)
#         1    0.000    0.000    0.000    0.000 contextual.py:36(<listcomp>)
#         2    0.000    0.000    0.000    0.000 shape_base.py:25(atleast_1d)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:592(transpose)
#         1    0.000    0.000    0.000    0.000 numeric.py:112(zeros_like)
#         1    0.000    0.000    4.738    4.738 contextual.py:55(predict)
#         2    0.000    0.000    0.000    0.000 base.py:325(_set_n_classes)
#         1    0.000    0.000    0.000    0.000 shape_base.py:286(hstack)
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    4.865    4.865 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 shape_base.py:335(<listcomp>)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         4    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00000000686FBC00}
#         1    0.000    0.000    0.000    0.000 contextual.py:47(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:21(__init__)
#         1    0.000    0.000    0.000    0.000 contextual.py:63(_create)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:26(_maybe_view_as_subclass)
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 index_tricks.py:642(__iter__)
#         1    0.000    0.000    0.000    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
