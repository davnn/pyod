# %% [markdown]
# # Performance Profiling of Contextual Detector

# %%
from __future__ import division
from __future__ import print_function

import os
import sys
from time import time

# temporary solution for relative imports in case pyod is not installed
# if pyod is installed, no need to use the following line
sys.path.append(
    os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

import numpy as np
from numpy import percentile
import matplotlib.pyplot as plt
import matplotlib.font_manager

# Import all models
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.feature_bagging import FeatureBagging
from pyod.models.hbos import HBOS
from pyod.models.iforest import IForest
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.pca import PCA
from pyod.models.lscp import LSCP
from pyod.models.contextual import ContextualDetector
from pyod.utils import generate_contextual_data

# %%
outliers_fraction = 0.1

# initialize a set of detectors for LSCP
detector_list = [LOF(n_neighbors=5), LOF(n_neighbors=10), LOF(n_neighbors=15),
                 LOF(n_neighbors=20), LOF(n_neighbors=25), LOF(n_neighbors=30),
                 LOF(n_neighbors=35), LOF(n_neighbors=40), LOF(n_neighbors=45),
                 LOF(n_neighbors=50)]

# %%
random_state = np.random.RandomState(42)
# Define nine outlier detection tools to be compared
classifiers = {
    'ABOD':
        ABOD(contamination=outliers_fraction),
    'CBLOF':
        CBLOF(contamination=outliers_fraction,
              check_estimator=False, random_state=random_state),
    'Feature Bagging':
        FeatureBagging(LOF(n_neighbors=35),
                       contamination=outliers_fraction,
                       random_state=random_state),
    'HBOS': HBOS(
        contamination=outliers_fraction),
    'Isolation Forest': IForest(contamination=outliers_fraction,
                                behaviour="new",
                                random_state=random_state),
    'KNN': KNN(
        contamination=outliers_fraction),
    'Average KNN': KNN(method='mean',
                       contamination=outliers_fraction),
    'LOF':
        LOF(n_neighbors=35, contamination=outliers_fraction),
    'MCD': MCD(
        contamination=outliers_fraction, random_state=random_state),
    'OCSVM': OCSVM(contamination=outliers_fraction),
    'PCA': PCA(
        contamination=outliers_fraction, random_state=random_state),
    'LSCP': LSCP(
        detector_list, contamination=outliers_fraction,
        random_state=random_state)
}

contextual_classifiers = {"Contextual " + k: ContextualDetector(base_detector=v) for k, v in classifiers.items()}
classifiers = {**classifiers, **contextual_classifiers}

# %%
X_train, X_test, y_train, y_test = generate_contextual_data(n_train=10000, n_test=10000, random_state=42)

# %%
def profile(classifier):
    # profile fit
    classifier.fit(X_train)

    # profile predict
    classifier.decision_function(X_test)

# %%
import cProfile
cProfile.run('profile(classifiers["Contextual LOF"])', sort="tottime")
# Out:
#          42933 function calls (42887 primitive calls) in 0.216 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         4    0.140    0.035    0.142    0.036 {method 'query' of 'sklearn.neighbors.kd_tree.BinaryTree' objects}
#         2    0.018    0.009    0.029    0.014 contextual.py:23(_contextualize)
#         4    0.012    0.003    0.013    0.003 lof.py:478(_local_reachability_density)
#        86    0.008    0.000    0.008    0.000 {built-in method numpy.array}
#        20    0.007    0.000    0.007    0.000 {built-in method numpy.concatenate}
#         4    0.005    0.001    0.156    0.039 base.py:333(kneighbors)
#         2    0.005    0.003    0.092    0.046 lof.py:437(_score_samples)
#         2    0.004    0.002    0.091    0.045 lof.py:216(fit)
#     40014    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         2    0.002    0.001    0.003    0.001 base.py:164(_fit)
#         4    0.002    0.001    0.002    0.001 {built-in method numpy.copyto}
#        36    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.001    0.001    0.093    0.046 lof.py:176(decision_function)
#         2    0.001    0.000    0.093    0.046 lof.py:145(fit)
#         2    0.000    0.000    0.094    0.047 contextual.py:39(_contextual_apply)
#         5    0.000    0.000    0.001    0.000 function_base.py:3846(_quantile_ureduce_func)
#         5    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.002    0.000 _methods.py:58(_mean)
#         2    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.001    0.000 validation.py:362(check_array)
#         2    0.000    0.000    0.000    0.000 function_base.py:4220(delete)
#        50    0.000    0.000    0.000    0.000 numeric.py:1557(normalize_axis_tuple)
#         4    0.000    0.000    0.143    0.036 parallel.py:866(__call__)
#        25    0.000    0.000    0.000    0.000 numeric.py:1620(moveaxis)
#       150    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       129    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        12    0.000    0.000    0.000    0.000 validation.py:40(_assert_all_finite)
#         3    0.000    0.000    0.000    0.000 _methods.py:91(_var)
#        16    0.000    0.000    0.000    0.000 parallel.py:78(get_active_backend)
#         8    0.000    0.000    0.000    0.000 _parallel_backends.py:187(get_nested_backend)
#        11    0.000    0.000    0.002    0.000 fromnumeric.py:3014(mean)
#         4    0.000    0.000    0.000    0.000 parallel.py:300(__call__)
#         8    0.000    0.000    0.143    0.018 parallel.py:735(dispatch_one_batch)
#         3    0.000    0.000    0.001    0.000 base.py:347(_process_decision_scores)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         4    0.000    0.000    0.000    0.000 utility.py:327(invert_order)
#       150    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#      38/2    0.000    0.000    0.000    0.000 copy.py:132(deepcopy)
#        24    0.000    0.000    0.000    0.000 numerictypes.py:365(issubdtype)
#         4    0.000    0.000    0.000    0.000 parallel.py:584(__init__)
#        48    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#       110    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         8    0.000    0.000    0.000    0.000 parallel.py:209(__init__)
#         8    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 _methods.py:48(_count_reduce_items)
#         8    0.000    0.000    0.000    0.000 version.py:307(parse)
#       8/4    0.000    0.000    0.000    0.000 parallel.py:669(_initialize_backend)
#         1    0.000    0.000    0.216    0.216 <ipython-input-5-3b9b7ee35998>:1(profile)
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:480(effective_n_jobs)
#       255    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        12    0.000    0.000    0.000    0.000 warnings.py:449(__enter__)
#         8    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#         4    0.000    0.000    0.142    0.036 parallel.py:220(__call__)
#         5    0.000    0.000    0.001    0.000 function_base.py:3354(_ureduce)
#        50    0.000    0.000    0.000    0.000 numeric.py:541(asanyarray)
#        12    0.000    0.000    0.000    0.000 validation.py:153(_shape_repr)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.216    0.216 {built-in method builtins.exec}
#        12    0.000    0.000    0.000    0.000 warnings.py:159(_add_filter)
#        12    0.000    0.000    0.000    0.000 validation.py:127(_num_samples)
#         8    0.000    0.000    0.000    0.000 shape_base.py:83(atleast_2d)
#         5    0.000    0.000    0.001    0.000 function_base.py:3564(percentile)
#       7/1    0.000    0.000    0.000    0.000 abc.py:196(__subclasscheck__)
#         8    0.000    0.000    0.006    0.001 shape_base.py:229(vstack)
#         4    0.000    0.000    0.143    0.036 parallel.py:698(_dispatch)
#         4    0.000    0.000    0.000    0.000 parallel.py:818(retrieve)
#        30    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         4    0.000    0.000    0.000    0.000 disk.py:41(memstr_to_bytes)
#         5    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 validation.py:903(check_is_fitted)
#        10    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 abc.py:180(__instancecheck__)
#        50    0.000    0.000    0.000    0.000 numeric.py:1607(<listcomp>)
#        12    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        36    0.000    0.000    0.000    0.000 validation.py:180(<genexpr>)
#        41    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 _parallel_backends.py:254(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 logger.py:39(short_format_time)
#        12    0.000    0.000    0.000    0.000 warnings.py:428(__init__)
#         4    0.000    0.000    0.000    0.000 threading.py:74(RLock)
#        12    0.000    0.000    0.000    0.000 warnings.py:143(simplefilter)
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 _methods.py:138(_std)
#         4    0.000    0.000    0.142    0.036 _parallel_backends.py:180(apply_async)
#         4    0.000    0.000    0.000    0.000 functools.py:44(update_wrapper)
#         8    0.000    0.000    0.000    0.000 base.py:453(<genexpr>)
#         4    0.000    0.000    0.000    0.000 validation.py:771(column_or_1d)
#         8    0.000    0.000    0.000    0.000 __init__.py:477(gen_even_slices)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:54(_wrapfunc)
#         5    0.000    0.000    0.000    0.000 function_base.py:3833(_quantile_is_valid)
#        10    0.000    0.000    0.000    0.000 shape_base.py:220(_warn_for_nonsequence)
#        23    0.000    0.000    0.000    0.000 numeric.py:469(asarray)
#        12    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        52    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         4    0.000    0.000    0.000    0.000 contextlib.py:59(__init__)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:1583(ravel)
#         4    0.000    0.000    0.142    0.036 base.py:286(_tree_query_parallel_helper)
#         1    0.000    0.000    0.110    0.110 contextual.py:49(fit)
#         4    0.000    0.000    0.000    0.000 parallel.py:186(unregister)
#         2    0.000    0.000    0.000    0.000 utility.py:366(_sklearn_version_20)
#        27    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 parallel.py:264(delayed)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:349(configure)
#        12    0.000    0.000    0.000    0.000 warnings.py:468(__exit__)
#        11    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 copy.py:236(_deepcopy_dict)
#         2    0.000    0.000    0.000    0.000 copy.py:268(_reconstruct)
#         2    0.000    0.000    0.093    0.046 contextual.py:41(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.142    0.036 parallel.py:224(<listcomp>)
#        89    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.count_nonzero}
#         4    0.000    0.000    0.000    0.000 parallel.py:183(__exit__)
#        12    0.000    0.000    0.000    0.000 validation.py:355(_ensure_no_complex_data)
#        16    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:93(take)
#         4    0.000    0.000    0.000    0.000 logger.py:23(_squeeze_time)
#         1    0.000    0.000    0.093    0.093 contextual.py:51(<dictcomp>)
#         4    0.000    0.000    0.142    0.036 _parallel_backends.py:546(__init__)
#         5    0.000    0.000    0.001    0.000 function_base.py:3821(_quantile_unchecked)
#         4    0.000    0.000    0.002    0.001 numeric.py:293(full)
#         4    0.000    0.000    0.000    0.000 base.py:124(_check_algorithm_metric)
#        18    0.000    0.000    0.000    0.000 base.py:1190(isspmatrix)
#         4    0.000    0.000    0.000    0.000 parallel.py:335(effective_n_jobs)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         4    0.000    0.000    0.000    0.000 shape_base.py:25(atleast_1d)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2083(any)
#         8    0.000    0.000    0.000    0.000 shape_base.py:283(<listcomp>)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3126(std)
#         8    0.000    0.000    0.000    0.000 _parallel_backends.py:36(__init__)
#        10    0.000    0.000    0.000    0.000 numeric.py:406(count_nonzero)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:197(reshape)
#         1    0.000    0.000    0.105    0.105 contextual.py:60(decision_function)
#        12    0.000    0.000    0.000    0.000 _config.py:12(get_config)
#        10    0.000    0.000    0.000    0.000 shape_base.py:209(_arrays_for_stack_dispatcher)
#        12    0.000    0.000    0.000    0.000 _methods.py:34(_sum)
#         4    0.000    0.000    0.000    0.000 contextlib.py:85(__exit__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2171(all)
#         8    0.000    0.000    0.000    0.000 version.py:312(<listcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:109(__init__)
#         4    0.000    0.000    0.000    0.000 contextlib.py:157(helper)
#         4    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#         2    0.000    0.000    0.000    0.000 shape_base.py:286(hstack)
#         4    0.000    0.000    0.000    0.000 parallel.py:167(__init__)
#         2    0.000    0.000    0.001    0.001 contextual.py:33(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 version.py:302(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 lof.py:150(__init__)
#         8    0.000    0.000    0.000    0.000 validation.py:950(<listcomp>)
#         8    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 context.py:232(get_context)
#        50    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        25    0.000    0.000    0.000    0.000 numeric.py:1683(<listcomp>)
#         4    0.000    0.000    0.000    0.000 version.py:331(_cmp)
#         4    0.000    0.000    0.000    0.000 functools.py:74(wraps)
#         2    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         2    0.000    0.000    0.093    0.046 contextual.py:62(<lambda>)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 contextlib.py:79(__enter__)
#         4    0.000    0.000    0.000    0.000 copy.py:252(_keep_alive)
#         2    0.000    0.000    0.007    0.003 contextual.py:34(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 version.py:51(__lt__)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:1785(shape)
#        36    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 copyreg.py:96(_slotnames)
#         4    0.000    0.000    0.000    0.000 process.py:155(daemon)
#        10    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 parallel.py:694(_terminate_backend)
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 shape_base.py:335(<listcomp>)
#         8    0.000    0.000    0.000    0.000 parallel.py:762(_print)
#         4    0.000    0.000    0.000    0.000 parallel.py:775(print_progress)
#         4    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:66(configure)
#        16    0.000    0.000    0.000    0.000 parallel.py:227(__len__)
#         3    0.000    0.000    0.000    0.000 base.py:325(_set_n_classes)
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         7    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:589(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         4    0.000    0.000    0.000    0.000 parallel.py:295(__init__)
#         4    0.000    0.000    0.000    0.000 copy.py:273(<genexpr>)
#         1    0.000    0.000    0.216    0.216 <string>:1(<module>)
#        34    0.000    0.000    0.000    0.000 copy.py:190(_deepcopy_atomic)
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         8    0.000    0.000    0.000    0.000 _parallel_backends.py:133(retrieval_context)
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:201(effective_n_jobs)
#         2    0.000    0.000    0.003    0.001 base.py:920(fit)
#         4    0.000    0.000    0.000    0.000 process.py:35(current_process)
#         8    0.000    0.000    0.000    0.000 _parallel_backends.py:85(compute_batch_size)
#        14    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:551(get)
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:89(batch_completed)
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 parallel.py:180(__enter__)
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:79(stop_call)
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:174(effective_n_jobs)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         4    0.000    0.000    0.000    0.000 parallel.py:274(delayed_function)
#         7    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         7    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:76(start_call)
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 contextual.py:52(<lambda>)
#         2    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00000000686FBC00}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         4    0.000    0.000    0.000    0.000 _parallel_backends.py:82(terminate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
